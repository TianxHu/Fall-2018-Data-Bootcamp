# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/Sweta/Desktop/Python/complete.data.iv.csv',encoding = 'latin-1', error_bad_lines = False)
import statsmodels.formula.api as smf

# %%
df
# Out:
#     shortnam                  name  yr.col    colonizer      continent  \
# 0        NaN                   NaN     NaN          NaN            NaN
# 1        AFG            Afganistan     NaN          NaN           Asia
# 2        NaN                   NaN     NaN          NaN            NaN
# 3        AGO                Angola  1483.0     Portugal         Africa
# 4        NaN                   NaN     NaN          NaN            NaN
# 5        ARE  United Arab Emirates  1507.0     Portugal           Asia
# 6        NaN                   NaN     NaN          NaN            NaN
# 7        ARG             Argentina  1512.0        Spain  South America
# 8        NaN                   NaN     NaN          NaN            NaN
# 9        ARM               Armenia     NaN          NaN           Asia
# 10       NaN                   NaN     NaN          NaN            NaN
# 11       AUS             Australia  1788.0      England          Other
# ...

# %%
df = df.replace('NaN', np.nan)
df = df.replace('..', np.nan)

# %%
df
# Out:
#     shortnam                  name  yr.col    colonizer      continent  \
# 0        NaN                   NaN     NaN          NaN            NaN
# 1        AFG            Afganistan     NaN          NaN           Asia
# 2        NaN                   NaN     NaN          NaN            NaN
# 3        AGO                Angola  1483.0     Portugal         Africa
# 4        NaN                   NaN     NaN          NaN            NaN
# 5        ARE  United Arab Emirates  1507.0     Portugal           Asia
# 6        NaN                   NaN     NaN          NaN            NaN
# 7        ARG             Argentina  1512.0        Spain  South America
# 8        NaN                   NaN     NaN          NaN            NaN
# 9        ARM               Armenia     NaN          NaN           Asia
# 10       NaN                   NaN     NaN          NaN            NaN
# 11       AUS             Australia  1788.0      England          Other
# ...

# %%
df = df.dropna(subset=['name','continent', 'colonizer', 'GDP05', 'Ethnic', 'Language'])
df
# Out:
#     shortnam                  name  yr.col    colonizer      continent  \
# 3        AGO                Angola  1483.0     Portugal         Africa
# 5        ARE  United Arab Emirates  1507.0     Portugal           Asia
# 7        ARG             Argentina  1512.0        Spain  South America
# 11       AUS             Australia  1788.0      England          Other
# 23       BFA          Burkina Faso  1896.0       France         Africa
# 25       BGD            Bangladesh  1537.0     Portugal           Asia
# 29       BHR               Bahrain  1521.0     Portugal           Asia
# 31       BHS          Bahamas, The  1718.0      England          Other
# 39       BOL               Bolivia  1524.0        Spain  South America
# 41       BRA                Brazil  1500.0     Portugal  South America
# 47       BWA              Botswana  1885.0      England         Africa
# 51       CAN                Canada  1535.0       France          Other
# ...

# %%
df['name'].nunique()
# Out:
# 72

# %%
df.columns
# Out:
# Index(['shortnam', 'name', 'yr.col', 'colonizer', 'continent', 'inst.age.1817',
#        'inst.age.1900', 'currentinst', 's.america', 'mortality', 'imputedmort',
#        'logem4', 'extmort4', 'excolony', 'logpgp12', 'lat_abst', 'avexpr',
#        'avelf', 'logpgp95', 'loghjypl', 'catho80', 'muslim80', 'no_cpm80',
#        'edes1975', 'malfal94', 'leb95', 'imr95', 'meantemp', 'lt100km',
#        'latabs', 'euro1900', 'democ1', 'cons1', 'indtime', 'democ00a',
#        'cons00a', 'africa', 'asia', 'other', 'f_brit', 'f_french', 'rich4',
#        'sjlofr', 'baseco', 'temp1', 'temp2', 'temp3', 'temp4', 'temp5',
#        'humid1', 'humid2', 'humid3', 'humid4', 'steplow', 'deslow', 'stepmid',
#        'desmid', 'drystep', 'drywint', 'landlock', 'goldm', 'iron', 'silv',
#        'zinc', 'oilres', 'yellow', 'idep', 'post1900', 'dur', 'Country Code',
#        'GDP05', 'Ethnic', 'Language', 'Religion', 'rol'],
#       dtype='object')

# %%
df.groupby('continent')['logpgp95'].describe()
# Out:
#                count      mean       std       min       25%       50%  \
# continent
# Africa          28.0  7.378724  0.799586  6.109248  6.829750  7.335856
# Asia            14.0  8.593545  1.181823  6.877296  7.447314  8.496450
# Other            7.0  9.496218  0.771269  7.904704  9.356255  9.756147
# South America   18.0  8.510876  0.471677  7.544332  8.229472  8.598778
#
#                     75%        max
# continent
# Africa         7.815874   8.907883
# Asia           9.759594  10.146430
# Other          9.942210  10.215740
# South America  8.829746   9.133459

# %%
Asia = df[df.continent == 'Asia']
Africa = df[df.continent == 'Africa']
South_America = df[df.continent == 'South America']

# %%
Asia
# Out:
#     shortnam                  name  yr.col colonizer continent  inst.age.1817  \
# 5        ARE  United Arab Emirates  1507.0  Portugal      Asia          310.0
# 25       BGD            Bangladesh  1537.0  Portugal      Asia          280.0
# 29       BHR               Bahrain  1521.0  Portugal      Asia          296.0
# 123      HKG  Hong Kong SAR, China  1842.0   England      Asia            0.0
# 133      IDN             Indonesia  1512.0  Portugal      Asia          305.0
# 135      IND                 India  1765.0   England      Asia           52.0
# 141      IRQ                  Iraq  1920.0   England      Asia            0.0
# 145      ISR                Israel  1917.0   England      Asia            0.0
# 171      LKA             Sri Lanka  1505.0  Portugal      Asia          312.0
# 195      MMR               Myanmar  1885.0   England      Asia            0.0
# 207      MYS              Malaysia  1511.0  Portugal      Asia          306.0
# ...

# %% [markdown]
# Just curious to see what was the average log of GDP in 1995 in eash of these regions, along with the duration of each region's colonization

# %%
Asia['logpgp95'].mean()
# Out:
# 8.593544714285715

# %%
Asia['dur'].mean()
# Out:
# 148.44444444444446

# %%
Africa
# Out:
#     shortnam              name  yr.col    colonizer continent  inst.age.1817  \
# 3        AGO            Angola  1483.0     Portugal    Africa          334.0
# 23       BFA      Burkina Faso  1896.0       France    Africa            0.0
# 47       BWA          Botswana  1885.0      England    Africa            0.0
# 59       CIV     Côte d'Ivoire  1843.0       France    Africa            0.0
# 61       CMR          Cameroon  1884.0      Germany    Africa            0.0
# 63       COG  Congo, Dem. Rep.  1885.0      Belgium    Africa            0.0
# 83       DZA           Algeria  1830.0       France    Africa            0.0
# 87       EGY  Egypt, Arab Rep.  1798.0       France    Africa           19.0
# 95       ETH          Ethiopia  1896.0       Italy     Africa            0.0
# 103      GAB             Gabon  1875.0       France    Africa            0.0
# 109      GHA             Ghana  1874.0      England    Africa            0.0
# ...

# %%
Africa['logpgp95'].mean()
# Out:
# 7.378724

# %%
Africa['dur'].mean()
# Out:
# 90.23076923076923

# %%
South_America['logpgp95'].mean()
# Out:
# 8.51087561111111

# %%
South_America['dur'].mean()
# Out:
# 282.6111111111111

# %% [markdown]
# Avg. GDP by Continent

# %%
df['GDP05']
# Out:
# 3       2387.825414
# 5      56199.029270
# 7       8522.522732
# 11     48760.355170
# 23       511.967590
# 25       598.617426
# 29     22066.071130
# 31     31023.047220
# 39      1720.099032
# 41      9495.484650
# 47      5512.811229
# 51     47181.562390
# 59      1216.208471
# 61      1264.154400
# 63      2503.312055
# 65      5312.082352
# 71      6954.039206
# 81      4414.812085
# 83      4273.312751
# 85      4286.515247
# 87      2112.487970
# 95       232.783200
# 103     9579.493437
# 109     1089.481796
# 111      619.185502
# 113      524.513949
# 115      522.489531
# 119     2638.290470
# 121     2446.651895
# 123    27688.698440
#            ...
# 191      666.257623
# 193    19585.124270
# 195      603.832089
# 205      373.232125
# 207     7983.952569
# 211      326.331710
# 213     1875.029642
# 215     1429.264574
# 223    32887.054610
# 225    17631.939690
# 227      974.537298
# 229     6172.395073
# 231     3831.364851
# 233     1818.315432
# ...

# %%
df['GDP05'] = df['GDP05'].astype(float)
# Out:
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.GDP05.dtype
# Out:
# dtype('float64')

# %%
Asia.groupby('name')['GDP05'].mean().plot.bar()

# %%
Africa.groupby('name')['GDP05'].mean().plot.bar()

# %%
South_America.groupby('name')['GDP05'].mean().plot.bar()

# %%
fig,ax = plt.subplots()

df.groupby('continent')['GDP05'].mean().plot.bar(x = 'continent', y = 'GDP05', ax=ax, figsize = (7,10))
ax.set_ylabel('Avg. GDP in 2005')
ax.set_xlabel('Continent')
ax.set_title('Avg. GDP by Continent in 2005')
# Out:
# Text(0.5,1,'Avg. GDP by Continent in 2005')

# %% [markdown]
# Institution Quality by Continent

# %%
fig,ax = plt.subplots()

df.groupby('continent')['avexpr'].mean().plot.bar(x = 'continent', y = 'avexpr', ax=ax, figsize = (7,10))
ax.set_ylabel('Avg. Protection Against Expropriation')
ax.set_xlabel('Continent')
ax.set_title('Avg. Protection Against Expropriation by Continent')
# Out:
# Text(0.5,1,'Avg. Protection Against Expropriation by Continent')

# %% [markdown]
# Mortality by Continent

# %%
fig,ax = plt.subplots()

df.groupby('continent')['mortality'].mean().plot.bar(x = 'continent', y = 'mortality', ax=ax, figsize = (7,9))
ax.set_ylabel('Mortality')
ax.set_xlabel('Continent')
ax.set_title('Mortality by Continent')
# Out:
# Text(0.5,1,'Mortality by Continent')

# %% [markdown]
# Also looked at the log of mortality to even out the results

# %%
fig,ax = plt.subplots()

df.groupby('continent')['logem4'].mean().plot.bar(x = 'continent', y = 'logem4', ax=ax, figsize = (7,9))
ax.set_ylabel('Log of Mortality')
ax.set_xlabel('Continent')
ax.set_title('Mortality by Continent')
# Out:
# Text(0.5,1,'Mortality by Continent')

# %% [markdown]
# Ethnographic Indicators

# %%
fig,ax = plt.subplots()

df.groupby('continent')['Ethnic'].mean().plot.bar(x = 'continent', y = 'avexpr', ax=ax, figsize = (7,10))
ax.set_ylabel('Average Ethinic Diversity')
ax.set_xlabel('Continent')
ax.set_title('Avg. Ethnic Diversity by Continent')
# Out:
# Text(0.5,1,'Avg. Ethinic Diversity by Continent')

# %%
fig,ax = plt.subplots()

df.groupby('continent')['Language'].mean().plot.bar(x = 'continent', y = 'avexpr', ax=ax, figsize = (7,10))
ax.set_ylabel('Average Language Diversity')
ax.set_xlabel('Continent')
ax.set_title('Avg. Language Diversity by Continent')
# Out:
# Text(0.5,1,'Avg. Language Diversity by Continent')

# %%
fig,ax = plt.subplots()

df.groupby('continent')['Religion'].mean().plot.bar(x = 'continent', y = 'avexpr', ax=ax, figsize = (7,10))
ax.set_ylabel('Average Religious Diversity')
ax.set_xlabel('Continent')
ax.set_title('Avg. Religious Diversity by Continent')
# Out:
# Text(0.5,1,'Avg. Religious Diversity by Continent')

# %% [markdown]
# Wanted to see who were the major colonizers in each region

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df['colonizer'].value_counts(normalize = True).plot.pie()

# %%
Asia['colonizer'].value_counts(normalize = True).plot.pie()

# %%
Africa['colonizer'].value_counts(normalize = True).plot.pie()

# %%
South_America['colonizer'].value_counts(normalize = True).plot.pie()

# %%
print(smf.ols('logpgp95 ~ dur', data = Africa).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     3.025
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):             0.0948
# Time:                        17:22:52   Log-Likelihood:                -27.513
# No. Observations:                  26   AIC:                             59.03
# Df Residuals:                      24   BIC:                             61.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0092      0.246     28.547      0.000       6.502       7.516
# ...

# %%
print(smf.ols('logpgp95 ~ dur', data = Asia).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.123
# Method:                 Least Squares   F-statistic:                    0.1257
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.733
# Time:                        17:22:52   Log-Likelihood:                -13.987
# No. Observations:                   9   AIC:                             31.97
# Df Residuals:                       7   BIC:                             32.37
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.7693      1.685      5.206      0.001       4.786      12.753
# ...

# %%
print(smf.ols('logpgp95 ~ dur', data = South_America).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     3.119
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):             0.0965
# Time:                        17:22:52   Log-Likelihood:                -9.8974
# No. Observations:                  18   AIC:                             23.79
# Df Residuals:                      16   BIC:                             25.58
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.3991      0.638     11.594      0.000       6.046       8.752
# ...

# %% [markdown]
# Looking at

# %%
df['logoil'] = np.log(df['oilres'])
# Out:
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#     shortnam                  name  yr.col    colonizer      continent  \
# 3        AGO                Angola  1483.0     Portugal         Africa
# 5        ARE  United Arab Emirates  1507.0     Portugal           Asia
# 7        ARG             Argentina  1512.0        Spain  South America
# 11       AUS             Australia  1788.0      England          Other
# 23       BFA          Burkina Faso  1896.0       France         Africa
# 25       BGD            Bangladesh  1537.0     Portugal           Asia
# 29       BHR               Bahrain  1521.0     Portugal           Asia
# 31       BHS          Bahamas, The  1718.0      England          Other
# 39       BOL               Bolivia  1524.0        Spain  South America
# 41       BRA                Brazil  1500.0     Portugal  South America
# 47       BWA              Botswana  1885.0      England         Africa
# 51       CAN                Canada  1535.0       France          Other
# ...

# %%
Asia
# Out:
#     shortnam                  name  yr.col colonizer continent  inst.age.1817  \
# 5        ARE  United Arab Emirates  1507.0  Portugal      Asia          310.0
# 25       BGD            Bangladesh  1537.0  Portugal      Asia          280.0
# 29       BHR               Bahrain  1521.0  Portugal      Asia          296.0
# 123      HKG  Hong Kong SAR, China  1842.0   England      Asia            0.0
# 133      IDN             Indonesia  1512.0  Portugal      Asia          305.0
# 135      IND                 India  1765.0   England      Asia           52.0
# 141      IRQ                  Iraq  1920.0   England      Asia            0.0
# 145      ISR                Israel  1917.0   England      Asia            0.0
# 171      LKA             Sri Lanka  1505.0  Portugal      Asia          312.0
# 195      MMR               Myanmar  1885.0   England      Asia            0.0
# 207      MYS              Malaysia  1511.0  Portugal      Asia          306.0
# ...

# %%
South_America
# Out:
#     shortnam                 name  yr.col colonizer      continent  \
# 7        ARG            Argentina  1512.0     Spain  South America
# 39       BOL              Bolivia  1524.0     Spain  South America
# 41       BRA               Brazil  1500.0  Portugal  South America
# 65       COL             Colombia  1499.0     Spain  South America
# 71       CRI           Costa Rica  1502.0     Spain  South America
# 81       DOM   Dominican Republic  1492.0     Spain  South America
# 85       ECU              Ecuador  1563.0     Spain  South America
# 119      GTM            Guatemala  1519.0     Spain  South America
# 125      HND             Honduras  1524.0     Spain  South America
# 149      JAM              Jamaica  1494.0     Spain  South America
# 187      MEX               Mexico  1521.0     Spain  South America
# 215      NIC            Nicaragua  1502.0     Spain  South America
# 229      PAN               Panama  1538.0     Spain  South America
# ...

# %%
Africa
# Out:
#     shortnam              name  yr.col    colonizer continent  inst.age.1817  \
# 3        AGO            Angola  1483.0     Portugal    Africa          334.0
# 23       BFA      Burkina Faso  1896.0       France    Africa            0.0
# 47       BWA          Botswana  1885.0      England    Africa            0.0
# 59       CIV     Côte d'Ivoire  1843.0       France    Africa            0.0
# 61       CMR          Cameroon  1884.0      Germany    Africa            0.0
# 63       COG  Congo, Dem. Rep.  1885.0      Belgium    Africa            0.0
# 83       DZA           Algeria  1830.0       France    Africa            0.0
# 87       EGY  Egypt, Arab Rep.  1798.0       France    Africa           19.0
# 95       ETH          Ethiopia  1896.0       Italy     Africa            0.0
# 103      GAB             Gabon  1875.0       France    Africa            0.0
# 109      GHA             Ghana  1874.0      England    Africa            0.0
# ...

# %% [markdown]
# Checking to see if having natural resources would affect GDP in 1995

# %%
Africa_Oil = Africa.replace('NaN', np.nan)

# %%
Africa_Oil = df.dropna(subset=['logoil','oilres'])
Africa_Oil
# Out:
#     shortnam                  name  yr.col    colonizer      continent  \
# 3        AGO                Angola  1483.0     Portugal         Africa
# 7        ARG             Argentina  1512.0        Spain  South America
# 11       AUS             Australia  1788.0      England          Other
# 23       BFA          Burkina Faso  1896.0       France         Africa
# 25       BGD            Bangladesh  1537.0     Portugal           Asia
# 29       BHR               Bahrain  1521.0     Portugal           Asia
# 31       BHS          Bahamas, The  1718.0      England          Other
# 39       BOL               Bolivia  1524.0        Spain  South America
# 41       BRA                Brazil  1500.0     Portugal  South America
# 47       BWA              Botswana  1885.0      England         Africa
# 51       CAN                Canada  1535.0       France          Other
# 59       CIV         Côte d'Ivoire  1843.0       France         Africa
# ...

# %%
Africa_Oil = Africa[Africa.oilres != 0.0]
Africa_Oil
Africa_Oil = Africa_Oil.dropna(subset=['logoil'])
Africa_Oil
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-303-0a96f0b6c6dc> in <module>()
#       1 Africa_Oil = Africa[Africa.oilres != 0.0]
#       2 Africa_Oil
# ----> 3 Africa_Oil = Africa_Oil.dropna(subset=['logoil'])
#       4 Africa_Oil
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['logoil']

# %%
Africa = df[df.continent == 'Africa']

# %%
print(smf.ols('avexpr ~ logoil', data = Africa_Oil).fit().summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~/anaconda3/lib/python3.7/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'logoil' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-305-80c419a23e6f> in <module>()
# ----> 1 print(smf.ols('avexpr ~ logoil', data = Africa_Oil).fit().summary())
#
# ...

# %%
Africa_NR = Africa_Oil.dropna(subset=['logoil', 'goldm', 'iron', 'zinc', 'silv'])
Africa_NR
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-306-fd34e09af804> in <module>()
# ----> 1 Africa_NR = Africa_Oil.dropna(subset=['logoil', 'goldm', 'iron', 'zinc', 'silv'])
#       2 Africa_NR
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['logoil']

# %%
print(smf.ols('logpgp95 ~ logoil + goldm + iron + silv + zinc', data = Africa_NR).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     2.170
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.170
# Time:                        17:22:54   Log-Likelihood:                -8.8369
# No. Observations:                  12   AIC:                             23.67
# Df Residuals:                       9   BIC:                             25.13
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7157      0.726      9.252      0.000       5.074       8.358
# ...

# %%
Ethno_df = df.dropna(subset=['Ethnic', 'Religion', 'Language',])
Ethno_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5a3ebf44a04> in <module>()
# ----> 1 Ethno_df = df.dropna(subset=['Ethnic', 'Religion', 'Language','logm4'])
#       2 Ethno_df
#
# NameError: name 'df' is not defined

# %%
print(smf.ols('avexpr ~ Ethnic + Religion + Language + logem4', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     6.906
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):           0.000129
# Time:                        18:35:53   Log-Likelihood:                -97.359
# No. Observations:                  63   AIC:                             204.7
# Df Residuals:                      58   BIC:                             215.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.6777      0.658     13.183      0.000       7.360       9.995
# ...

# %%
print(smf.ols('logpgp95 ~ Ethnic + Religion + Language', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     9.770
# Date:                Tue, 18 Dec 2018   Prob (F-statistic):           2.21e-05
# Time:                        18:35:16   Log-Likelihood:                -87.021
# No. Observations:                  67   AIC:                             182.0
# Df Residuals:                      63   BIC:                             190.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.0855      0.301     30.188      0.000       8.484       9.687
# ...

# %%
print(smf.ols('logpgp95 ~ Ethnic + Religion + Language', data = Africa).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     2.779
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):             0.0630
# Time:                        17:22:54   Log-Likelihood:                -28.785
# No. Observations:                  28   AIC:                             65.57
# Df Residuals:                      24   BIC:                             70.90
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.6549      0.478     18.098      0.000       7.668       9.642
# ...

# %%
print(smf.ols('logpgp95 ~ Ethnic + Religion + Language', data = Asia).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                 -0.058
# Method:                 Least Squares   F-statistic:                    0.7621
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.541
# Time:                        17:22:54   Log-Likelihood:                -20.244
# No. Observations:                  14   AIC:                             48.49
# Df Residuals:                      10   BIC:                             51.04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.4503      1.403      5.312      0.000       4.325      10.575
# ...

# %%
print(smf.ols('logpgp95 ~ Ethnic + Religion + Language', data = South_America).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                 -0.172
# Method:                 Least Squares   F-statistic:                    0.1679
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.916
# Time:                        17:22:54   Log-Likelihood:                -11.182
# No. Observations:                  18   AIC:                             30.36
# Df Residuals:                      14   BIC:                             33.93
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.6547      0.414     20.891      0.000       7.766       9.543
# ...

# %%
Asia[['logpgp95', 'Ethnic', 'Language', 'Religion','logem4' ]].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fdecbbb5e1c1> in <module>()
# ----> 1 Asia[['logpgp95', 'Ethnic', 'Language', 'Religion','logem4' ]].corr()
#
# NameError: name 'Asia' is not defined

# %%
# Part (a)
fig, ax = plt.subplots(1,3)
Asia[['Ethnic', 'logpgp95']].plot.scatter('Ethnic', 'logpgp95', ax=ax[0], figsize = (15,5))
Asia[['Language', 'logpgp95']].plot.scatter('Language', 'logpgp95', ax=ax[1])
Asia[['Religion', 'logpgp95']].plot.scatter('Religion', 'logpgp95', ax=ax[2])

ax[0].set_title('Ethnolinguistic Correlations with GDP in Asia', loc = 'left')
# Out:
# Text(0,1,'Ethnolinguistic Correlations with GDP in Asia')

# %%
South_America[['logpgp95', 'Ethnic', 'Language', 'Religion' ]].corr()
# Out:
#           logpgp95    Ethnic  Language  Religion
# logpgp95  1.000000 -0.001123 -0.159578 -0.077156
# Ethnic   -0.001123  1.000000  0.018092  0.102199
# Language -0.159578  0.018092  1.000000 -0.111140
# Religion -0.077156  0.102199 -0.111140  1.000000

# %%
fig, ax = plt.subplots(1,3)
South_America[['Ethnic', 'logpgp95']].plot.scatter('Ethnic', 'logpgp95', ax=ax[0], figsize = (15,5))
South_America[['Language', 'logpgp95']].plot.scatter('Language', 'logpgp95', ax=ax[1])
South_America[['Religion', 'logpgp95']].plot.scatter('Religion', 'logpgp95', ax=ax[2])

ax[0].set_title('Ethnolinguistic Correlations with GDP in South America', loc = 'left')
# Out:
# Text(0,1,'Ethnolinguistic Correlations with GDP in South America')

# %%
Africa[['logpgp95', 'Ethnic', 'Language', 'Religion' ]].corr()
# Out:
#           logpgp95    Ethnic  Language  Religion
# logpgp95  1.000000 -0.482920 -0.324883 -0.171501
# Ethnic   -0.482920  1.000000  0.644236  0.556082
# Language -0.324883  0.644236  1.000000  0.544359
# Religion -0.171501  0.556082  0.544359  1.000000

# %%
fig, ax = plt.subplots(1,3)
Africa[['Ethnic', 'logpgp95']].plot.scatter('Ethnic', 'logpgp95', ax=ax[0], figsize = (15,5))
Africa[['Language', 'logpgp95']].plot.scatter('Language', 'logpgp95', ax=ax[1])
Africa[['Religion', 'logpgp95']].plot.scatter('Religion', 'logpgp95', ax=ax[2])

ax[0].set_title('Ethnolinguistic Correlations with GDP in Asia', loc = 'left')
# Out:
# Text(0,1,'Ethnolinguistic Correlations with GDP in Asia')

# %%
print(smf.ols('avexpr ~ landlock', data = Africa).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     3.539
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):             0.0704
# Time:                        17:22:55   Log-Likelihood:                -44.789
# No. Observations:                  30   AIC:                             93.58
# Df Residuals:                      28   BIC:                             96.38
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1545      0.223     27.608      0.000       5.698       6.611
# ...

# %%
print(smf.ols('avexpr ~ colonizer', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                    0.6062
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.749
# Time:                        17:22:55   Log-Likelihood:                -127.47
# No. Observations:                  72   AIC:                             270.9
# Df Residuals:                      64   BIC:                             289.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    4.6818      1.507      3.106      0.003       1.670       7.693
# ...

# %%
print(smf.ols('logpgp95 ~ avexpr + landlock', data = South_America).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     7.745
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):            0.00489
# Time:                        17:22:55   Log-Likelihood:                -5.1159
# No. Observations:                  18   AIC:                             16.23
# Df Residuals:                      15   BIC:                             18.90
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.3154      0.658      9.600      0.000       4.913       7.718
# ...

# %%
print(smf.ols('logpgp95 ~ avexpr + landlock', data = Asia).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                     12.13
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):            0.00453
# Time:                        17:22:55   Log-Likelihood:                -16.796
# No. Observations:                  14   AIC:                             37.59
# Df Residuals:                      12   BIC:                             38.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7423      1.412      2.650      0.021       0.665       6.819
# ...

# %%
print(smf.ols('logpgp95 ~ avexpr + landlock', data = Africa).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     4.146
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):             0.0279
# Time:                        17:22:55   Log-Likelihood:                -28.949
# No. Observations:                  28   AIC:                             63.90
# Df Residuals:                      25   BIC:                             67.89
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.1499      0.822      6.266      0.000       3.457       6.842
# ...

# %%
print(smf.ols('avexpr ~ logem4', data = South_America).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1.431
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.249
# Time:                        17:22:55   Log-Likelihood:                -21.613
# No. Observations:                  18   AIC:                             47.23
# Df Residuals:                      16   BIC:                             49.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.1842      3.062      3.326      0.004       3.693      16.675
# ...

# %%
print(smf.ols('avexpr ~ logem4', data = Asia).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     1.678
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.227
# Time:                        17:22:55   Log-Likelihood:                -16.960
# No. Observations:                  11   AIC:                             37.92
# Df Residuals:                       9   BIC:                             38.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.3165      1.762      5.287      0.001       5.330      13.303
# ...

# %%
print(smf.ols('avexpr ~ logem4', data = Africa).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.2620
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):              0.613
# Time:                        17:22:55   Log-Likelihood:                -41.601
# No. Observations:                  27   AIC:                             87.20
# Df Residuals:                      25   BIC:                             89.79
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.4448      1.061      6.074      0.000       4.260       8.630
# ...

# %%
print(smf.ols('avexpr ~ logem4', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 avexpr   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     22.58
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):           1.27e-05
# Time:                        17:22:56   Log-Likelihood:                -99.711
# No. Observations:                  63   AIC:                             203.4
# Df Residuals:                      61   BIC:                             207.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.2195      0.576     16.016      0.000       8.068      10.371
# ...

# %%
import seaborn as sns
fig,ax = plt.subplots(figsize=(10, 6))
sns.regplot(x="avexpr", y="logpgp95", data=df, ax=ax)
# Out:
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(smf.ols('logpgp95 ~ avexpr | logem4'), data = df).fit().summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-38a730c37717> in <module>()
# ----> 1 print(smf.ols('logpgp95 ~ avexpr | logem4'), data = df).fit().summary()
#
# TypeError: from_formula() missing 1 required positional argument: 'data'

# %%
sns.pairplot(df, x_vars = ["Ethnic", "Religion", "Language"], y_vars =["logpgp95"], hue="continent", height=8, aspect=.6, kind="reg")
# Out:
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(Africa, x_vars = ["avexpr"], y_vars =["logpgp95"], height=8, aspect=.6, kind="reg")
# Out:
# /Users/Sweta/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(smf.ols('logpgp95 ~ avexpr + colonizer + logem4 + avelf + oilres + goldm + iron + zinc + silv + Ethnic + Language + Religion', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.777
# Method:                 Least Squares   F-statistic:                     12.44
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):           2.51e-11
# Time:                        17:22:58   Log-Likelihood:                -31.416
# No. Observations:                  60   AIC:                             100.8
# Df Residuals:                      41   BIC:                             140.6
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    7.3696      0.801      9.196      0.000       5.751       8.988
# ...

# %%
print(smf.ols('logpgp95 ~ avexpr + colonizer + logem4 + Ethnic + Language + Religion', data = df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logpgp95   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     17.84
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):           1.32e-13
# Time:                        17:24:34   Log-Likelihood:                -35.935
# No. Observations:                  60   AIC:                             97.87
# Df Residuals:                      47   BIC:                             125.1
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    7.5331      0.775      9.725      0.000       5.975       9.091
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea8415b8a3ee> in <module>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined
